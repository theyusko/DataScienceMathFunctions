# %%
import hypergeometricfunctions as hg

import numpy as np
from numpy import linalg
from scipy.stats import * 
from math import *
from matplotlib import pyplot as plt
import seaborn as sns
import statistics as sts
from mpl_toolkits.mplot3d import Axes3D

# %%
N = 30 # population size
A = 10 # num of desired items in N
n = 15 # total number of draws made
t = 5  # num of desired items in our draw of n items

print(hg.hypergeom_cdf(N,A,n,t)) # P( X <= t)
hg.hypergeom_plot(N,A,n)

"""Genelal finding cdf from pdf"""
#pdf = 1
#np.sum([pdf for x in range(min_value, t+1)])
# Out:
# 0.6500749625187406
# 'Genelal finding cdf from pdf'

# %%
"""
From HW.
Plotting CDF & PDF from sample data
"""

mu = 0
sigma = 2
x = np.random.normal(loc=mu, scale=sigma, size=50)
y = np.random.normal(loc=mu, scale=sigma, size=5000)

plt.hist(x, bins='auto', density=True, alpha=0.7)
plt.hist(y, bins='auto', density=True, alpha=0.7)

plt.xlabel("X and Y")
plt.ylabel("Frequency")
plt.title("Histogram of X and Y")
plt.show()

# %%
pdf_x = norm.pdf(x)
pdf_y = norm.pdf(y)

cdf_x = norm.cdf(x)
pdf_y = norm.pdf(y)

plt.hist(x, bins='auto', density=True, alpha=0.7)
plt.plot(np.sort(x), np.sort(cdf_x)) 
sns.lineplot(x=x, y=pdf_x)

plt.xlabel("X")
plt.ylabel("Frequency")
plt.title("Histogram, CDF, PDF of X")
plt.show(x, cdf_x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-f6562a33c70a> in <module>
#      12 plt.ylabel("Frequency")
#      13 plt.title("Histogram, CDF, PDF of X")
# ---> 14 plt.show(x, cdf_x)
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# /usr/lib/python3/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      47         # only call close('all') if any to close
#      48         # close triggers gc.collect, which can be slow
# ---> 49         if close and Gcf.get_all_fig_managers():
#      50             matplotlib.pyplot.close('all')
#      51
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
"""Plotting CDF from a known PDF"""
# cdf of X = x^5 / 32 , where 0 <= x <= 2 

space = np.linspace(0,2,100) # start, end, sample size
x = pow(space, 5) / 32
plt.plot(space, x)
plt.show()

# %%
"""PDF & CDF of multivariate pdfs"""
x = np.linspace(-5,5,1000) 
y = np.linspace(-5,5,1000) 
X, Y = np.meshgrid(x,y)

pos = np.empty(X.shape + (2,)) 
pos[:, :, 0] = X; pos[:, :, 1] = Y

rv = multivariate_normal([0, 1], [[1, 0], [0, 2]])

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, rv.pdf(pos),cmap='viridis',linewidth=0) 
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis') 
plt.title("PDF") 
plt.show()

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, rv.cdf(pos),cmap='viridis',linewidth=0) 
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis') 
ax.set_zlabel('Z axis') 
plt.title("CDF") 
plt.show()

# %%
def expected_val(array):

# %%
"""MT Questions"""

student_ID = '010170520'
array = [int(digit) for digit in student_ID]*3
bins = len(set(student_ID)) # number of distinct digits in student_ID

plt.hist(np.sort(array), bins=bins, density=True, alpha=0.7)

plt.xlabel("Student ID distribution")
plt.ylabel("Frequency of digits")
plt.title("Histogram of frequency of digits in student ID")

cdf = norm.cdf(array)
plt.plot(np.sort(array), np.sort(cdf)) 
plt.show(x, cdf_x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-097cdab33f97> in <module>
#      13 cdf = norm.cdf(array)
#      14 plt.plot(np.sort(array), np.sort(cdf))
# ---> 15 plt.show(x, cdf_x)
#      16
#      17 print("mean: " + str(np.mean(array)) + "\t expected value" + str(np.average(array)) )
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# /usr/lib/python3/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      47         # only call close('all') if any to close
#      48         # close triggers gc.collect, which can be slow
# ---> 49         if close and Gcf.get_all_fig_managers():
#      50             matplotlib.pyplot.close('all')
#      51
#
# ...

# %%
print("mean: " + str(np.mean(array)) + "\t expected value" + str(np.average(array)) )

# If expected value should differ from mean, which happens when the distribution 
# doesnt have uniform weights, add those weights in np.average
# Out:
# mean: 1.7777777777777777	 expected value1.7777777777777777

# %%
""" Exponential PDF sample plot"""
x = np.linspace(0,7,100) # start, end, sample size

pdf = 1 * (e**(-1*x))
sns.lineplot(x, pdf, color="red")

pdf = 2 * (e**(-2*x))
sns.lineplot(x, pdf, color="blue")
# Out:
# /home/yusko/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/yusko/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pdf = 1 * (e**(-1*x))

sns.lineplot(x, np.cumsum(pdf), color="red")

pdf = 2 * (e**(-2*x))
sns.lineplot(x, np.cumsum(pdf), color="blue")
# Out:
# /home/yusko/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/yusko/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
